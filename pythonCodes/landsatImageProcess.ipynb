# %%
# !pip install rasterio
# !pip install numpy
# !pip install matplotlib
# !pip install -U scikit-image
# !pip install boto3
# !pip install watermark
# !pip install nb_black
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rasterio in /home/gabriel/.local/lib/python3.8/site-packages (1.2.10)
# Requirement already satisfied: affine in /home/gabriel/.local/lib/python3.8/site-packages (from rasterio) (2.3.0)
# Requirement already satisfied: snuggs>=1.4.1 in /home/gabriel/.local/lib/python3.8/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: cligj>=0.5 in /home/gabriel/.local/lib/python3.8/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in /home/gabriel/.local/lib/python3.8/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click>=4.0 in /home/gabriel/.local/lib/python3.8/site-packages (from rasterio) (8.0.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from rasterio) (2019.11.28)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from rasterio) (1.17.4)
# Requirement already satisfied: attrs in /home/gabriel/.local/lib/python3.8/site-packages (from rasterio) (21.2.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from rasterio) (45.2.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /home/gabriel/.local/lib/python3.8/site-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (1.17.4)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/gabriel/.local/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in /usr/lib/python3/dist-packages (from matplotlib) (1.17.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib) (2.7.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib) (1.14.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in /home/gabriel/.local/lib/python3.8/site-packages (0.18.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: imageio>=2.3.0 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (2.10.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (3.4.3)
# Requirement already satisfied: scipy>=1.0.1 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (1.7.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (2021.10.12)
# Requirement already satisfied: numpy>=1.16.5 in /usr/lib/python3/dist-packages (from scikit-image) (1.17.4)
# Requirement already satisfied: networkx>=2.0 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/gabriel/.local/lib/python3.8/site-packages (from scikit-image) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/gabriel/.local/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.7.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.14.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: boto3 in /home/gabriel/.local/lib/python3.8/site-packages (1.19.4)
# Requirement already satisfied: botocore<1.23.0,>=1.22.4 in /home/gabriel/.local/lib/python3.8/site-packages (from boto3) (1.22.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/gabriel/.local/lib/python3.8/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/gabriel/.local/lib/python3.8/site-packages (from boto3) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/lib/python3/dist-packages (from botocore<1.23.0,>=1.22.4->boto3) (2.7.3)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/lib/python3/dist-packages (from botocore<1.23.0,>=1.22.4->boto3) (1.25.8)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: watermark in /home/gabriel/.local/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: ipython in /home/gabriel/.local/lib/python3.8/site-packages (from watermark) (7.28.0)
# Requirement already satisfied: pickleshare in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->watermark) (4.6.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (3.0.20)
# Requirement already satisfied: backcall in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (0.1.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->watermark) (45.2.0)
# Requirement already satisfied: decorator in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (5.1.0)
# Requirement already satisfied: traitlets>=4.2 in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (0.18.0)
# Requirement already satisfied: pygments in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->watermark) (2.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/gabriel/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython->watermark) (0.8.2)
# Requirement already satisfied: wcwidth in /home/gabriel/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nb_black in /home/gabriel/.local/lib/python3.8/site-packages (1.0.7)
# Requirement already satisfied: black>='19.3' in /home/gabriel/.local/lib/python3.8/site-packages (from nb_black) (21.9b0)
# Requirement already satisfied: ipython in /home/gabriel/.local/lib/python3.8/site-packages (from nb_black) (7.28.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/gabriel/.local/lib/python3.8/site-packages (from black>='19.3'->nb_black) (3.10.0.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/gabriel/.local/lib/python3.8/site-packages (from black>='19.3'->nb_black) (0.4.3)
# Requirement already satisfied: click>=7.1.2 in /home/gabriel/.local/lib/python3.8/site-packages (from black>='19.3'->nb_black) (8.0.3)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in /home/gabriel/.local/lib/python3.8/site-packages (from black>='19.3'->nb_black) (1.2.2)
# Requirement already satisfied: regex>=2020.1.8 in /home/gabriel/.local/lib/python3.8/site-packages (from black>='19.3'->nb_black) (2021.10.23)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.8/dist-packages (from black>='19.3'->nb_black) (2.4.0)
# Requirement already satisfied: pathspec<1,>=0.9.0 in /home/gabriel/.local/lib/python3.8/site-packages (from black>='19.3'->nb_black) (0.9.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->nb_black) (45.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (3.0.20)
# Requirement already satisfied: backcall in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->nb_black) (4.6.0)
# Requirement already satisfied: pickleshare in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (0.7.5)
# Requirement already satisfied: decorator in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (5.1.0)
# Requirement already satisfied: pygments in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (0.18.0)
# Requirement already satisfied: matplotlib-inline in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (0.1.3)
# Requirement already satisfied: traitlets>=4.2 in /home/gabriel/.local/lib/python3.8/site-packages (from ipython->nb_black) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/gabriel/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython->nb_black) (0.8.2)
# Requirement already satisfied: wcwidth in /home/gabriel/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->nb_black) (0.2.5)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

# %%
# %load_ext watermark

# %%
# %load_ext nb_black

# %%
import rasterio
from rasterio.plot import show
import numpy
import matplotlib.pyplot as plt

import skimage.exposure

# access package for AWS access
import boto3

import sys
import os
import subprocess
import datetime
import platform
import datetime

# %%
fpath = 'https://landsat-pds.s3.amazonaws.com/c1/L8/219/076/LC08_L1TP_219076_20210603_20210608_01_T1/LC08_L1TP_219076_20210603_20210608_01_T1_B2.TIF'

# %%
src_image = rasterio.open(fpath)
print(src_image.profile)
# Out:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 7621, 'height': 7721, 'count': 1, 'crs': CRS.from_epsg(32623), 'transform': Affine(30.0, 0.0, 228285.0,
#        0.0, -30.0, -2441385.0), 'blockxsize': 512, 'blockysize': 512, 'tiled': True, 'compress': 'deflate', 'interleave': 'band'}

# %%
fig, ax = plt.subplots(1, figsize=(12, 10))
show(src_image, ax=ax)
ax.set_title(
    'Pure Landsat-8 band 2 (Blue): Pass 0219, row 071 \nSão Paulo, Jacareí e São José dos Campos '
)
plt.show()

# %%
# convert image to numpy

src_image_array = src_image.read(1)
src_image_array = src_image_array.astype('f4')

# replace zero items (ie array pixels out of image frame) with nan

src_image_array[src_image_array == 0] = numpy.nan

# %%
fig, ax = plt.subplots(1, figsize=(12, 10))
show(src_image_array, ax=ax)
ax.set_title(
    'Black Borders removed from Landsat-8 band 4: Pass 0089, row 071 \nSão Paulo, Jacareí e São José dos Campos'
)
plt.show()

# %%
# clean up big data objects

src_image_array = 0
src_image = 0

# %%
def normalize(array):
    '''
    normalize: normalize a numpy array so all value are between 0 and 1
    '''
    array_min, array_max = array.min(), array.max()
    return (array - array_min) / (array_max - array_min)


# end normalize

# %%
def make_color_image(b1: int, b2: int, b3: int, fpath: str):
    '''
    make_false_color_image: combine nominated Landsat-8 bands into false color image
    
    Parameters:
    b1, b2, b3 int - values between 1 - 6 (inclusive), being a Landsat-8 band number
    
    fpath str - template for URL to Landsat-8 data
    
    Band Number Description       Wavelength Resolution
    Band 1      Coastal / Aerosol 0.433 to 0.453 µm 30 meter
    Band 2      Visible blue      0.450 to 0.515 µm 30 meter
    Band 3      Visible green     0.525 to 0.600 µm 30 meter
    Band 4      Visible red       0.630 to 0.680 µm 30 meter
    Band 5      Near-infrared     0.845 to 0.885 µm 0 meter
    Band 6      Short wavelength infrared 1.56 to 1.66 µm 30 meter
    
    Environment:
    assumes rasterio imported as rio
    assumes boto package  available for AWS file storage access
    '''

    if not (
        b1 > 0
        and b2 > 0
        and b3 > 0
        and b1 < 7
        and b2 < 7
        and b3 < 7
    ):
        raise ValueError(
            f'One or more invalid Landsat-8 band number {b1}, {b2}, {b3} supplied'
        )
    # endif

    # create URLs for each band
    b1_path = fpath[:-5] + f'{b1}.TIF'
    b2_path = fpath[:-5] + f'{b2}.TIF'
    b3_path = fpath[:-5] + f'{b3}.TIF'
    print(b1_path)

    # open URL with rasterio
    b1 = rasterio.open(b1_path)
    b2 = rasterio.open(b2_path)
    b3 = rasterio.open(b3_path)

    # read into numpy array
    b1_np = b1.read(1)
    b2_np = b2.read(1)
    b3_np = b3.read(1)

    # normalize data to 0<->1
    b1_norm = normalize(b1_np)
    b2_norm = normalize(b2_np)
    b3_norm = normalize(b3_np)

    # create three color image
    rgb = numpy.dstack((b1_norm, b2_norm, b3_norm))

    return rgb


# end make_color_image

# %%
# read true color image
rbg = make_color_image(4, 3, 2, fpath)

fig, ax = plt.subplots(1, figsize=(12, 10))
ax.set_title(
    'Landsat-8 bands 4, 3, 2 True Color: Pass 0219, row 071 \nSão Paulo, Jacareí e São José dos Campos ')
plt.imshow(rbg)

# %%
def remove_black_borders(band):
  band = band.astype('f4')

  # replace zero items (ie array pixels out of image frame) with nan
  band[band == 0] = numpy.nan

  return band

# %%
def make_color_image_eqh(
    b1: int, b2: int, b3: int, fpath: str, method: str
):
    '''
    Parameters:
    b1, b2, b3 int - values between 1 - 8 (inclusive), being a Landsat-8 band number
    
    fpath str - template for URL to Landsat-8 data
    
    Band Number Description       Wavelength Resolution
    Band 1      Coastal / Aerosol 0.433 to 0.453 µm 30 meter
    Band 2      Visible blue      0.450 to 0.515 µm 30 meter
    Band 3      Visible green     0.525 to 0.600 µm 30 meter
    Band 4      Visible red       0.630 to 0.680 µm 30 meter
    Band 5      Near-infrared     0.845 to 0.885 µm 0 meter
    Band 6      Short wavelength infrared 1.56 to 1.66 µm 30 meter
    '''

    # create URLs for each band
    b1_path = fpath[:-5] + f'{b1}.TIF'
    b2_path = fpath[:-5] + f'{b2}.TIF'
    b3_path = fpath[:-5] + f'{b3}.TIF'

    # open URL with rasterio
    b1 = rasterio.open(b1_path)
    b2 = rasterio.open(b2_path)
    b3 = rasterio.open(b3_path)

    # read into numpy array
    b1_np = b1.read(1)
    b2_np = b2.read(1)
    b3_np = b3.read(1)

    if method == 'eqh_hist':
        eq_b1 = skimage.exposure.equalize_hist(b1_np)
        eq_b2 = skimage.exposure.equalize_hist(b2_np)
        eq_b3 = skimage.exposure.equalize_hist(b3_np)
    
    if method == 'eqh_adapt':
        eq_b1 = skimage.exposure.equalize_adapthist(b1_np)
        eq_b2 = skimage.exposure.equalize_adapthist(b2_np)
        eq_b3 = skimage.exposure.equalize_adapthist(b3_np)

    # normalize data to 0<->1
    b1_norm = normalize(eq_b1)
    b2_norm = normalize(eq_b2)
    b3_norm = normalize(eq_b3)

    # create three color image
    rgb = numpy.dstack((b1_norm, b2_norm, b3_norm))

    # naip_data = numpy.moveaxis(rgb.squeeze(),-1,0) # move axis with 4 entries to beginning and remove extra dimension
    # naip_data_raster_reshaped = rasterio.plot.reshape_as_raster(naip_data)
    # print(naip_data_raster_reshaped) # check new shape, should be (4,3445,4703)

    # # if they are equal, naip_meta doesn't need to be updated, otherwise update it
    # with rasterio.open('RGB.tiff','w',**b1.profile) as dst:
    #     dst.write(naip_data_raster_reshaped)

    # with rasterio.open('BadRGB.tiff','w',driver='Gtiff', width=b1.width, height=b1.height,count=3,crs=b1.crs,transform=b1.transform, dtype=b1.dtypes[0]) as teste:
    #     teste.write(b1_np,1)
    #     teste.write(b2_np,2)
    #     teste.write(b3_np,3)
    #     teste.close()

    return rgb

# %%
rgb = make_color_image_eqh(4, 3, 2, fpath, 'eqh_hist')

fig, ax = plt.subplots(1, figsize=(12, 10))
ax.set_title(
    'Landsat-8 bands 4, 3, 2 Equalized: True Color : Pass 0219, row 071 \nSão Paulo, Jacareí e São José dos Campos '
)

plt.imshow(rgb)

# %%
# %watermark
# Out:
# Last updated: 2021-10-27T09:05:14.487440-03:00
#
# Python implementation: CPython
# Python version       : 3.8.10
# IPython version      : 7.28.0
#
# Compiler    : GCC 9.3.0
# OS          : Linux
# Release     : 5.11.0-38-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit

# %%
# %watermark -h -iv
# Out:
# Hostname: gabriel-H170M-D3H
#
# matplotlib: 3.4.3
# platform  : 1.0.8
# boto3     : 1.19.4
# sys       : 3.8.10 (default, Sep 28 2021, 16:10:42)
# [GCC 9.3.0]
# skimage   : 0.18.3
# numpy     : 1.17.4
# rasterio  : 1.2.10
